# %% [markdown]
# <div style="margin-bottom: 120px;">
#     <div style="float:left;">
#         <br/>
#         <img src="img/udc.png" width="300"/>
#     </div>
# </div>
#
# <h1 style="color: #d60e8c; text-align:center;">Procesado de datos</h1>

# %% [markdown]
# <h1>Contenidos</h1>
#
# <div class="alert alert-block alert-info"
#      style="margin-top: 20px; padding-top:0px; padding-bottom:0px;border: 1px solid #d60e8c; border-radius: 20px; background:transparent;">
#     <ol>
#         <li><a href="#intro">Introducción</a></li>
#         <li><a href="#about_dataset">Descripción del conjunto de datos</a></li>
#         <li><a href="#analysis">Lectura y análisis de los datos </a></li>
#         <li><a href="#division">División del conjunto de datos en datos en entrada y salida</a></li>
#         <li><a href="#split">División de los datos para entrenamiento y prueba</a></li>
#         <li><a href="#oversampling">Balanceo de datos</a></li>
#         <li><a href="#scale">Normalización</a></li>
#         <li><a href="#pca">PCA</a></li>
#         <li><a href="#classification">Ejercicio</a></li>
#     </ol>
# </div>
# <br>

# %% [markdown]
# <a name="intro"></a>
# <h1 style="color: #d60e8c;">Introducción</h1>
# <hr style="border: 0.5px solid #d60e8c;">

# %% [markdown]
# El objetivo de esta práctica es realizar un informe técnico que analice el funcionamiento de al menos dos técnicas de aprendizaje supervisado sobre un conjunto de datos etiquetados, de modo que se pueda realizar una caracterización objetiva de su funcionamiento en base a los resultados obtenidos.

# %% [markdown]
# ## Importamos las librerías
#
# Comenzamos importando las librerías que se utilizarán:

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import time

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn import preprocessing
from sklearn.decomposition import PCA
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import NearMiss

# %% [markdown]
# <a name="about_dataset"></a>
# <h1 style="color: #d60e8c;">Descripción del conjunto de datos</h1>
# <hr style="border: 0.5px solid #d60e8c;">

# %% [markdown]
# Se utilizará un conjunto de datos sobre setas laminadas. Todos los atributos se definen mediante palabras o texto. Los datos fueron recolectados
# de la "Guía de campo de la Sociedad Audubon".
# <br><br>
# El conjunto de datos original incluye descripciones de muestras hipotéticas correspondientes a 23 especies de setas con láminas de la familia Agaricus y Lepiota (pp. 500-525). Cada especie se identifica como claramente comestible o claramente venenosa en función de las siguientes cualidades:
# <ul>
#     <li><b>poisonous</b>: Si es una seta venenosa o comestible </li>
#     <li><b>cap-shape</b>: Forma del sombrero de la seta</li>
#     <li><b>cap-surface</b>: Tipo de superficie del sombrero de la seta</li>
#     <li><b>cap-color</b>: Color del sombrero de la seta</li>
#     <li><b>bruises</b>: Hematomas o manchas</li>
#     <li><b>odor</b>: Olor</li>
#     <li><b>gill-attachment</b>: Inserción de las láminas </li>
#     <li><b>gill-spacing</b>: Espaciado de las láminas </li>
#     <li><b>gill-size</b> Tamaño de las láminas</li>
#     <li><b>gill-color</b>: Color de las branquias</li>
#     <li><b>stalk-shape</b>: Forma del tallo</li>
#     <li><b>stalk-root</b>: Raíz del tallo </li>
#     <li><b>stalk-surface-above-ring</b>: Superficie del tallo por encima del anillo</li>
#     <li><b>stalk-surface-below-ring</b>: Superficie del tallo por debajo del anillo</li>
#     <li><b>stalk-color-above-ring</b>: Color del tallo por encima del anillo</li>
#     <li><b>stalk-color-below-ring</b>: color del tallo por debajo del anillo</li>
#     <li><b>veil-type</b>: Tipo de velo </li>
#     <li><b>veil-color</b>: Color del velo </li>
#     <li><b>ring-number</b>: Número de anillos </li>
#     <li><b>ring-type</b>: Tipo de anillos </li>
#     <li><b>spore-print-color</b>: Color de la huella de esporas </li>
#     <li><b>population</b>: Tipo de población que forman </li>
#     <li><b>habitat</b>: Hábitat en el que crecen</li>
#
# </ul>
#
# [Enlace al repositorio](https://archive.ics.uci.edu/dataset/73/mushroom)

# %% [markdown]
# <a name="analysis"></a>
# <h1 style="color: #d60e8c;">Lectura y análisis de los datos</h1>
# <hr style="border: 0.5px solid #d60e8c;">

# %% [markdown]
# El archivo con el conjunto de datos tiene valores perdidos en el dataset, con lo que, cuando leemos el archivo, indicamos que existen valores perdidos con <code>na_values=["?"]</code> (de esta forma, estamos indicando que los valores perdidos están representados por el carácter "?"). Así, en la lectura del archivo, esos valores las celdas que contengan el valor "?" serán convertidas a valores nulos y posteriormente se filtrarán.

# %%
df_orig=pd.read_csv('mushroms1.csv', na_values=["?"]) #Lectura de los datos y conversión del símbolo "?" a NaN
df_orig.head()
# Out:
#   poisonous cap-shape cap-surface cap-color  bruises    odor gill-attachment  \
# 0    EDIBLE    CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 1    EDIBLE    CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 2    EDIBLE    CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 3    EDIBLE    CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
# 4    EDIBLE    CONVEX      SMOOTH     WHITE  BRUISES  ALMOND            FREE
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0      CROWDED    NARROW      WHITE  ...                   SMOOTH
# 1      CROWDED    NARROW      WHITE  ...                   SMOOTH
# 2      CROWDED    NARROW       PINK  ...                   SMOOTH
# 3      CROWDED    NARROW       PINK  ...                   SMOOTH
# 4      CROWDED    NARROW      BROWN  ...                   SMOOTH
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                  WHITE                  WHITE   PARTIAL      WHITE
# 1                  WHITE                  WHITE   PARTIAL      WHITE
# 2                  WHITE                  WHITE   PARTIAL      WHITE
# 3                  WHITE                  WHITE   PARTIAL      WHITE
# 4                  WHITE                  WHITE   PARTIAL      WHITE
#
#   ring-number ring-type spore-print-color population habitat
# 0         ONE   PENDANT            PURPLE    SEVERAL   WOODS
# 1         ONE   PENDANT             BROWN    SEVERAL   WOODS
# 2         ONE   PENDANT            PURPLE    SEVERAL   WOODS
# 3         ONE   PENDANT             BROWN    SEVERAL   WOODS
# 4         ONE   PENDANT            PURPLE    SEVERAL   WOODS
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Eliminación de filas con información incompleta
#
# 1. Se consultan las dimensiones del conjunto de datos:

# %%
df_orig.shape #Se consulta la dimensión del conjunto de datos
# Out:
# (8417, 23)

# %% [markdown]
# 2. Se realiza un recuento de los valores nulos que se tienen en cada columna. Se ve que hay bastantes valores nulos en la columna **stalk-root** y 1 valor nulo en todas las columnas menos en la columna de **poisonous**.

# %%
df_orig.isnull().sum() #Contabilización de la cantidad de muestras para las que faltan datos en cada atributo o característica
# Out:
# poisonous                      0
# cap-shape                      1
# cap-surface                    1
# cap-color                      1
# bruises                        1
# odor                           1
# gill-attachment                1
# gill-spacing                   1
# gill-size                      1
# gill-color                     1
# stalk-shape                    1
# stalk-root                  2481
# stalk-surface-above-ring       1
# stalk-surface-below-ring       1
# stalk-color-above-ring         1
# stalk-color-below-ring         1
# veil-type                      1
# veil-color                     1
# ring-number                    1
# ring-type                      1
# spore-print-color              1
# population                     1
# habitat                        1
# dtype: int64

# %% [markdown]
# 3. Se eliminan las filas que contienen algún valor nulo en alguna de sus columnas, ya que tienen información incompleta.

# %%
df=df_orig.dropna(axis=0) #Se elimnan las filas que contienen alguna columna que tenga un valor nulo y se guarda todo en la variable "df"

# %% [markdown]
# 4. Se consultan las dimensiones del dataset tras eliminar las filas con valores nulos.

# %%
df.shape #Se consulta la dimensión del conjunto de datos
# Out:
# (5936, 23)

# %% [markdown]
# 5. Se consulta de nuevo los valores nulos para verificar que ya no existen. Ahora el resultado debería ser 0 para todas las columnas.

# %%
df.isnull().sum() #Se consulta si existe algún valor nulo
# Out:
# poisonous                   0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %% [markdown]
# 6. Ahora se comprobará que tenemos unos valores de la columna de **poisonous** equilibrados entre setas comestibles y venenosas:

# %%
df['poisonous'].value_counts() #Agrupa los valores únicos que hay en la columna "Poisonous" y nos devuelve la cuenta.
# Out:
# poisonous
# EDIBLE       3768
# POISONOUS    2168
# Name: count, dtype: int64

# %% [markdown]
# <a name="division"></a>
# <h1 style="color: #d60e8c;">Transformación de los valores del conjunto de datos de texto a número</h1>
# <hr style="border: 0.5px solid #d60e8c;">

# %% [markdown]
# Para poder trabajar con el conjunto de datos que se ha analizado y ajustado anteriormente, es necesario pasar todos los valores que sean de texto en alguna columna a número, para evitar errores y poder implementar los algoritmos de clasificación.
#
# A continuación se incluye el código completo con el que se han ido transformando todos los valores a número, además de a qué número entero le corresponde cada palabra:

# %%
encoder = preprocessing.OrdinalEncoder(dtype=int) #Se le ordena que convierta palabaras a números enteros
df_encoded = encoder.fit_transform(df[['poisonous', "cap-shape","cap-surface","cap-color","bruises","odor",
                                      "gill-attachment","gill-spacing","gill-size","gill-color","stalk-shape","stalk-root",
                                      "stalk-surface-above-ring","stalk-surface-below-ring","stalk-color-above-ring",
                                      "stalk-color-below-ring","veil-type","veil-color","ring-number","ring-type",
                                      "spore-print-color","population","habitat"]])
encoder.categories_ #Muestra el diccionario que la herramienta "encoder" ha creado
# Out:
# [array(['EDIBLE', 'POISONOUS'], dtype=object),
#  array(['BELL', 'CONICAL', 'CONVEX', 'FLAT', 'KNOBBED', 'SUNKEN'],
#        dtype=object),
#  array(['FIBROUS', 'GROOVES', 'SCALY', 'SMOOTH'], dtype=object),
#  array(['BROWN', 'BUFF', 'CINNAMON', 'GRAY', 'PINK', 'RED', 'WHITE',
#         'YELLOW'], dtype=object),
#  array(['BRUISES', 'NO'], dtype=object),
#  array(['ALMOND', 'ANISE', 'CREOSOTE', 'FOUL', 'MUSTY', 'NONE', 'PUNGENT'],
#        dtype=object),
#  array(['ATTACHED', 'FREE'], dtype=object),
#  array(['CLOSE', 'CROWDED'], dtype=object),
#  array(['BROAD', 'NARROW'], dtype=object),
#  array(['BLACK', 'BROWN', 'CHOCOLATE', 'GRAY', 'GREEN', 'PINK', 'PURPLE',
#         'WHITE', 'YELLOW'], dtype=object),
#  array(['ENLARGING', 'TAPERING'], dtype=object),
#  array(['BULBOUS', 'CLUB', 'EQUAL', 'ROOTED'], dtype=object),
#  array(['FIBROUS', 'SCALY', 'SILKY', 'SMOOTH'], dtype=object),
#  array(['FIBROUS', 'SCALY', 'SILKY', 'SMOOTH'], dtype=object),
#  array(['BROWN', 'BUFF', 'CINNAMON', 'GRAY', 'PINK', 'WHITE', 'YELLOW'],
#        dtype=object),
#  array(['BROWN', 'BUFF', 'CINNAMON', 'GRAY', 'PINK', 'WHITE', 'YELLOW'],
#        dtype=object),
#  array(['PARTIAL'], dtype=object),
#  array(['WHITE', 'YELLOW'], dtype=object),
#  array(['NONE', 'ONE', 'TWO'], dtype=object),
#  array(['EVANESCENT', 'LARGE', 'NONE', 'PENDANT'], dtype=object),
#  array(['BLACK', 'BROWN', 'CHOCOLATE', 'GREEN', 'PURPLE', 'WHITE'],
#        dtype=object),
#  array(['ABUNDANT', 'CLUSTERED', 'NUMEROUS', 'SCATTERED', 'SEVERAL',
#         'SOLITARY'], dtype=object),
#  array(['GRASSES', 'LEAVES', 'MEADOWS', 'PATHS', 'URBAN', 'WOODS'],
#        dtype=object)]

# %% [markdown]
# Este es el texto presente en el archivo .csv, y acontinuación se mostrarán las correspondencias numéricas:

# %%
df_encoded
# Out:
# array([[0, 2, 3, ..., 4, 4, 5],
#        [0, 2, 3, ..., 1, 4, 5],
#        [0, 2, 3, ..., 4, 4, 5],
#        ...,
#        [0, 3, 2, ..., 5, 4, 3],
#        [0, 3, 2, ..., 5, 5, 3],
#        [0, 3, 2, ..., 5, 4, 3]], shape=(5936, 23))

# %%
#Se guardan en cada una de las columnas de la variable "df" todos los datos originales convertidos a número

df["poisonous"] = df_encoded[:,0]
df["cap-shape"] = df_encoded[:,1]
df["cap-surface"] = df_encoded[:,2]
df["cap-color"] = df_encoded[:,3]
df["bruises"] = df_encoded[:,4]
df["odor"] = df_encoded[:,5]
df["gill-attachment"] = df_encoded[:,6]
df["gill-spacing"] = df_encoded[:,7]
df["gill-size"] = df_encoded[:,8]
df["gill-color"] = df_encoded[:,9]
df["stalk-shape"] = df_encoded[:,10]
df["stalk-root"] = df_encoded[:,11]
df["stalk-surface-above-ring"] = df_encoded[:,12]
df["stalk-surface-below-ring"] = df_encoded[:,13]
df["stalk-color-above-ring"] = df_encoded[:,14]
df["stalk-color-below-ring"] = df_encoded[:,15]
df["veil-type"] = df_encoded[:,16]
df["veil-color"] = df_encoded[:,17]
df["ring-number"] = df_encoded[:,18]
df["ring-type"] = df_encoded[:,19]
df["spore-print-color"] = df_encoded[:,20]
df["population"] = df_encoded[:,21]
df["habitat"] = df_encoded[:,22]

# %% [markdown]
# <a name="division"></a>
# <h1 style="color: #d60e8c;">División del conjunto de datos en datos de entrada y salida</h1>
# <hr style="border: 0.5px solid #d60e8c;">

# %% [markdown]
# Se obtienen los atributos que caracterizan nuestro conjunto de datos:

# %%
df.columns
# Out:
# Index(['poisonous', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='str')

# %% [markdown]
# Se seleccionan las columnas que utilizaremos como entradas y las convertimos en un <b>array de NumPy</b>, para poder utilizarlo con los algoritmos de <b>scikit-learn</b>:

# %%
feature_df = df[df.columns[1:df.shape[1]]] #Se cogen todas las columnas menos la primera.
X = feature_df #Se define el conjunto de datos de entrada
X_readed = np.asarray(feature_df) #Se convierte el conjunto de datos de entrada en una matriz NumPy
X_readed[0:5]
# Out:
# array([[2, 3, 6, 0, 0, 1, 1, 1, 7, 1, 0, 3, 3, 5, 5, 0, 0, 1, 3, 4, 4, 5],
#        [2, 3, 6, 0, 0, 1, 1, 1, 7, 1, 0, 3, 3, 5, 5, 0, 0, 1, 3, 1, 4, 5],
#        [2, 3, 6, 0, 0, 1, 1, 1, 5, 1, 0, 3, 3, 5, 5, 0, 0, 1, 3, 4, 4, 5],
#        [2, 3, 6, 0, 0, 1, 1, 1, 5, 1, 0, 3, 3, 5, 5, 0, 0, 1, 3, 1, 4, 5],
#        [2, 3, 6, 0, 0, 1, 1, 1, 1, 1, 0, 3, 3, 5, 5, 0, 0, 1, 3, 4, 4, 5]])

# %% [markdown]
# Y ahora los datos de salida, si la seta es venenosa o no:

# %%
y_readed = np.asarray(df['poisonous']) #Se coge la primera columna como dato de salida
y_readed[0:5]
# Out:
# array([0, 0, 0, 0, 0])

# %% [markdown]
# <a name="split"></a>
# <h1 style="color: #d60e8c;">División en datos de entrenamiento y prueba</h1>
# <hr style="border: 0.5px solid #d60e8c;">
# El siguiente código, utiliza el 75% del conjunto de datos para entrenar el modelo y el 25% para test (valores por defecto si no se fija el tamaño en los parámetros), ya que se tiene una gran cantidad de datos y se considera que no es necesario utilizar más del 75% de los datos para obtener unos resultados fiables.

# %%
X_train, X_test, y_train, y_test = train_test_split(X_readed, y_readed, random_state = 1)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (4452, 22) (4452,)
# Test set: (1484, 22) (1484,)

# %% [markdown]
# <a name="oversampling"></a>
# <h1 style="color: #d60e8c;">Balanceo de datos</h1>
# <hr style="border: 0.5px solid #d60e8c;">
#
# Como se ha podido observar con anterioridad, la cantidad de valores en la columna de **poisonous** que se corresponden con setas comestibles y con setas venenosas no es la misma, siendo su diferencia igual a 1600 muestras, lo que supone que un 63% de las setas estudiadas son comestibles y un 37% son venenosas. Esto puede influir en la capacidad del algoritmo para predecir correctamente la clase minoritaria (en este caso que una seta sea venenosa), ya que al estar menos representada este puede ignorarla, haciendo que el cálculo de la precisión del modelo no se asemeje completamente a la realidad.
#
# Por lo tanto, para corregir esto, se utiliza la librería <a href="https://imbalanced-learn.org/stable/index.html"><b>imbalanced-learn</b></a> para realizar el balanceo del conjunto de datos, quitando muestras en los casos mayoritarios para obtener el conjunto final sobre el que se trabajará (Undersampling):

# %%
unique, counts = np.unique(y_train, return_counts=True) #Escanea la variable "y_train" y contabiliza cuantas muestras hay de cada tipo
sm = NearMiss() #Inicializa el algoritmo NearMiss y lo guarda en la variable "sm"
X_train, y_train= sm.fit_resample(X_train, y_train) #Se elimina el exceso de muestras de la clase mayoritaria y se sobreescriben las variables X_train e y_train con los datos ya balanceados.
print("Número de muestras de cada tipo: ",counts)
print('\nBalanceado undersampling:', X_train.shape,  y_train.shape)
unique, counts = np.unique(y_train, return_counts=True) 
print(dict(zip(unique, counts))) #Comprobación de que el proceso de balanceado se ha realizado con éxito
# Out:
# Número de muestras de cada tipo:  [2828 1624]
#
# Balanceado undersampling: (3248, 22) (3248,)
# {np.int64(0): np.int64(1624), np.int64(1): np.int64(1624)}

# %% [markdown]
# Por otro lado, también se comprobará cual es el resultado final obtenido si se añaden muestras al caso minoritario hasta igualar ambas partes del conjunto de datos:

# %%
unique, counts = np.unique(y_train, return_counts=True) #Escanea y cuenta cuántas setas hay de cada tipo antes de hacer la transformación.
sm = SMOTE(random_state=1) #Inicializa el algoritmo SMOTE y lo guarda en la variable "sm"
X_train, y_train= sm.fit_resample(X_train, y_train) #Generación de muestras sintéticas del tipo minoriario (setas venenosas) y se sobreescriben las variables X_train e y_train con los datos ya balanceados.

print('\nBalanceado oversampling:', X_train.shape,  y_train.shape)
unique, counts = np.unique(y_train, return_counts=True)
print(dict(zip(unique, counts))) #Comprobación de que el proceso de balanceado se ha realizado con éxito
# Out:
# Balanceado oversampling: (3248, 22) (3248,)
# {np.int64(0): np.int64(1624), np.int64(1): np.int64(1624)}

# %% [markdown]
# <a name="scale"></a>
# <h1 style="color: #d60e8c;">Normalización</h1>
# <hr style="border: 0.5px solid #d60e8c;">
#
# Ahora se procederá a realizar la normalización del conjunto de datos. Esto permitirá evitar que los algoritmos tengan un sesgo y aprendan mejor unas características que otras, buscando que estos datos sigan una distribución normal. Para ello, se transforman los datos para centrarlos, eliminando el valor medio de cada característica y a continuación, se escalan dividiendo las características por su desviación estándar.
#
# Como la librería <code>scikit-learn</code> dispone de un módulo para procesado de datos <code>preprocessing</code> se va a utilizar <code>StandardScaler</code> (<a href="https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html#sklearn.preprocessing.StandardScaler">documentación</a>).  Que, una vez entrenado, se puede utilizar posteriormente sobre nuevos datos.

# %%
#Ejecución de ambos escalados para la obtención de la gráfica

scaler = StandardScaler()

X_train_std = scaler.fit_transform(X_train) # aplica los cálculos sobre el conjunto de datos de entrada para escalarlos
X_test_std = scaler.transform(X_test)

scaler = preprocessing.MinMaxScaler()

X_train_minmax = scaler.fit_transform(X_train) # aplica los cálculos sobre el conjunto de datos de entrada para escalarlos
X_test_minmax = scaler.transform(X_test)

import seaborn as sns

# X_readed es el array original (sin escalar) de 22 atributos
# Asumimos que la columna 3 es el índice 2 y la columna 4 es el índice 3
col3_orig = X_readed[:, 2] 
col4_orig = X_readed[:, 3]

# 3. Se definen los datos después del StandardScaler para la gráfica
col3_std = X_train_std[:, 2]
col4_std = X_train_std[:, 3]

# 3. Se definen los datos después del MinMaxScaler para la gráfica
col3_minmax = X_train_minmax[:, 2]
col4_minmax = X_train_minmax[:, 3]

# 4. Dibujar las gráficas
plt.style.use('ggplot')
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Gráfica 1: Antes de Escalar
sns.kdeplot(data=col3_orig, ax=axes[0], label='Sup. sombrero', fill=True, alpha=0.3)
sns.kdeplot(data=col4_orig, ax=axes[0], label='Color sombrero', fill=True, alpha=0.3)
axes[0].set_title('Antes de Escalar')
axes[0].set_ylabel('Densidad')
axes[0].set_xlabel('Valor numérico')
axes[0].legend()

# Gráfica 2: Después de Standard Scaler
sns.kdeplot(data=col3_std, ax=axes[1], label='Sup. sombrero', fill=True, alpha=0.3)
sns.kdeplot(data=col4_std, ax=axes[1], label='Color sombrero', fill=True, alpha=0.3)
axes[1].set_title('Después del Standard Scaler')
axes[1].set_ylabel('Densidad')
axes[1].set_xlabel('Valor numérico')
axes[1].legend()

# Gráfica 3: Después de Min-Max Scaling
sns.kdeplot(data=col3_minmax, ax=axes[2], label='Sup. sombrero', fill=True, alpha=0.3, clip=(0, 1))
sns.kdeplot(data=col4_minmax, ax=axes[2], label='Color sombrero', fill=True, alpha=0.3, clip=(0, 1))
axes[2].set_title('Después del Min-Max Scaling')
axes[2].set_ylabel('Densidad')
axes[2].set_xlabel('Valor numérico')
axes[2].legend()

plt.tight_layout()
plt.show()

# %%
#Escalado Estándar

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train) # aplica los cálculos sobre el conjunto de datos de entrada para escalarlos
X_test = scaler.transform(X_test)

# %%
#Escalado Min/Max

scaler = preprocessing.MinMaxScaler()

X_train_minmax = scaler.fit_transform(X_train) # aplica los cálculos sobre el conjunto de datos de entrada para escalarlos
X_test_minmax = scaler.transform(X_test)

# %% [markdown]
# <a name="pca"></a>
# <h1 style="color: #d60e8c;">PCA</h1>
# <hr style="border: 0.5px solid #d60e8c;">
#
# Aplicando el Análisis de componentes principales (PCA) se tratará de buscar conjuntos de ejes de coordenadas en los que algunas de las dimensiones no sean necesarias utilizando algoritmos que centren los ejes en el origen de coordenadas restando la media.
#
# Para aplicar el Análisis de componentes principales (PCA) se utilizará el algoritmo <code>PCA</code> (<a href="https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html?highlight=pca#sklearn.decomposition.PCA">documentación del algoritmo</a>) implementado la librería <code>scikit-learn</code> sobre el conjunto de datos. Antes de utilizar PCA para extraer **n** componentes principales, lo utilizaresmos sin parámetros de forma que podemos analizar el porcentaje de varianza de todos los componentes utilizando "explained_variance_ratio_", que devuelve una lista, en este caso con 22 elementos porque vamos a usar los trece atributos, donde cada elemento de la lista indica el porcentaje de variabilidad que representa ese componente y, como utilizamos todos los componentes, la suma de todos los porcentajes, es decir, la suma de todos los elementos de la lista dará 1 como resultado.

# %%
mypca = PCA()
mypca.fit(X_train)

mypca.explained_variance_ratio_
# Out:
# array([2.41857768e-01, 1.42240621e-01, 8.65990786e-02, 8.08885701e-02,
#        6.40137440e-02, 5.76765555e-02, 4.47480997e-02, 4.12197748e-02,
#        3.57202805e-02, 3.22573205e-02, 3.12839266e-02, 2.81522482e-02,
#        2.26938102e-02, 1.78534455e-02, 1.77641649e-02, 1.57918264e-02,
#        1.45773231e-02, 1.13401975e-02, 8.63416513e-03, 2.72329219e-03,
#        1.96378806e-03, 2.64257430e-18])

# %%
mypca.explained_variance_ratio_.sum()  # Suma todos los elementos de la lista
# Out:
# np.float64(1.0)

# %% [markdown]
# A partir de <code>explained_variance_ratio_</code>, podemos calcular la varianza acumulada de los componentes:</li>

# %%
print("\n Varianza que aporta cada componente:")
variance = mypca.explained_variance_ratio_
print(variance)

print("\n Varianza acumulada:")
acumvar = variance.cumsum()

for i in range(len(acumvar)):
    print(f" {(i+1):2} componentes: {acumvar[i]:.8f} ")

X_axis=np.linspace(1,22,22)
# Out:
#  Varianza que aporta cada componente:
# [2.41857768e-01 1.42240621e-01 8.65990786e-02 8.08885701e-02
#  6.40137440e-02 5.76765555e-02 4.47480997e-02 4.12197748e-02
#  3.57202805e-02 3.22573205e-02 3.12839266e-02 2.81522482e-02
#  2.26938102e-02 1.78534455e-02 1.77641649e-02 1.57918264e-02
#  1.45773231e-02 1.13401975e-02 8.63416513e-03 2.72329219e-03
#  1.96378806e-03 2.64257430e-18]
#
#  Varianza acumulada:
#   1 componentes: 0.24185777
#   2 componentes: 0.38409839
#   3 componentes: 0.47069747
#   4 componentes: 0.55158604
#   5 componentes: 0.61559978
#   6 componentes: 0.67327634
#   7 componentes: 0.71802444
#   8 componentes: 0.75924421
#   9 componentes: 0.79496449
#  10 componentes: 0.82722181
#  11 componentes: 0.85850574
#  12 componentes: 0.88665799
#  13 componentes: 0.90935180
#  14 componentes: 0.92720524
#  15 componentes: 0.94496941
#  16 componentes: 0.96076123
#  17 componentes: 0.97533856
#  18 componentes: 0.98667875
#  19 componentes: 0.99531292
#  20 componentes: 0.99803621
#  21 componentes: 1.00000000
#  22 componentes: 1.00000000

# %%
plt.style.use('ggplot')
plt.figure(figsize=(10, 4))

# Gráfica 1: Antes de Escalar
plt.plot(X_axis,acumvar, label="Varianza acumulada")
plt.xticks(np.arange(0, 23, 1))
plt.title('Varianza acumulada')
plt.ylabel('Suma de varianza')
plt.xlabel('Nº de componente')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Aquí se puede observar como a partir del decimoquinto componente la varianza acumulada tiene un valor muy cercano al 95%, esto quiere decir que los datos que se van a perder se corresponden con el 5% de los datos totales. Es por ello que se decide tomar un total de 15 componentes para realizar el cálculo del PCA, ya que con menos componentes las pérdidas de datos se consideran demasiado grandes todavía.

# %% [markdown]
# <h3>Projección con 15 componentes</h3>

# %%
mypca15 = PCA(n_components=15)
mypca15.fit(X_train)
values_proj15 = mypca15.transform(X_train)
X_test_PCA = mypca15.transform(X_test)

print(values_proj15.shape)

X_projected15 = mypca15.inverse_transform(values_proj15)
loss15 = ((X_train - X_projected15) ** 2).mean()

print("Projection loss (15 components): " + str(loss15))

X_projected15.shape
# Out:
# (3248, 15)
# Projection loss (15 components): 0.05252920184300113
# (3248, 22)

# %% [markdown]
# <a name="classification"></a>
# # <font style="color:#d60e8c;">Clasificación</font>
# <hr style="border: 0.5px solid #d60e8c;">

# %% [markdown]
# ## KNN

# %% [markdown]
# Ahora, será importante determinar el número de vecinos que queremos considerar a la hora de hacer predicciones. Se estudiarán dos casos, un valor de k alto, muy estable y poco sensible al ruido aunque puede perder detalles, o un valor de k bajo que es un modelo flexible y que se adapta muy bien a variaciones y detalles, pero es muy sensible al ruido.

# %%
Score = np.zeros(95)
Score_desvest = np.zeros(95)
Posicion = np.zeros(95)
Time = np.zeros(95)
for i in range(5,100):
    k = i   # Número de vecinos
    Score_ind=np.zeros(5)
    Posicion_ind=np.zeros(5)
    Time_ind=np.zeros(5)
    for u in range (1,6):
        ini = time.time()
        # Creamos nuestra instancia de nuestro algoritmo KNN con K vecinos
        neigh = KNeighborsClassifier(n_neighbors = k)
        neigh.fit(values_proj15,y_train)
        y_predict_knn = neigh.predict(X_test_PCA)
        
        Time_ind[u-1] = (time.time() - ini)*1000
        Score_ind[u-1] = neigh.score(X_test_PCA, y_test)
        Posicion_ind[u-1] = i
    Time[i-5] = np.mean(Time_ind)
    Score[i-5] = np.mean(Score_ind)
    Score_desvest[i-5] = np.std(Score_ind)
    Posicion[i-5] = i
    print(f"Tiempo entrenamiento para k={i}  = {Time[i-5]} ms") 
    print("Exactitud media obtenida con k-NN para k={i}: ".format(i=i), neigh.score(X_test_PCA, y_test))

plt.style.use('ggplot')
plt.figure(figsize=(10, 4))
# Out:
# Tiempo entrenamiento para k=5  = 88.92450332641602 ms
# Exactitud media obtenida con k-NN para k=5:  0.9797843665768194
# Tiempo entrenamiento para k=6  = 84.69786643981934 ms
# Exactitud media obtenida con k-NN para k=6:  0.9811320754716981
# Tiempo entrenamiento para k=7  = 83.27264785766602 ms
# Exactitud media obtenida con k-NN para k=7:  0.9777628032345014
# Tiempo entrenamiento para k=8  = 94.12765502929688 ms
# Exactitud media obtenida con k-NN para k=8:  0.9777628032345014
# Tiempo entrenamiento para k=9  = 97.51167297363281 ms
# Exactitud media obtenida con k-NN para k=9:  0.977088948787062
# Tiempo entrenamiento para k=10  = 105.09881973266602 ms
# Exactitud media obtenida con k-NN para k=10:  0.9777628032345014
# Tiempo entrenamiento para k=11  = 98.08950424194336 ms
# Exactitud media obtenida con k-NN para k=11:  0.9750673854447439
# Tiempo entrenamiento para k=12  = 89.93358612060547 ms
# Exactitud media obtenida con k-NN para k=12:  0.9764150943396226
# Tiempo entrenamiento para k=13  = 99.91226196289062 ms
# Exactitud media obtenida con k-NN para k=13:  0.9757412398921833
# Tiempo entrenamiento para k=14  = 97.28875160217285 ms
# Exactitud media obtenida con k-NN para k=14:  0.9764150943396226
# Tiempo entrenamiento para k=15  = 103.4693717956543 ms
# Exactitud media obtenida con k-NN para k=15:  0.9743935309973046
# Tiempo entrenamiento para k=16  = 97.45550155639648 ms
# Exactitud media obtenida con k-NN para k=16:  0.9750673854447439
# Tiempo entrenamiento para k=17  = 107.81469345092773 ms
# Exactitud media obtenida con k-NN para k=17:  0.9737196765498652
# Tiempo entrenamiento para k=18  = 105.06906509399414 ms
# Exactitud media obtenida con k-NN para k=18:  0.9743935309973046
# Tiempo entrenamiento para k=19  = 107.71098136901855 ms
# Exactitud media obtenida con k-NN para k=19:  0.9737196765498652
# Tiempo entrenamiento para k=20  = 107.80019760131836 ms
# Exactitud media obtenida con k-NN para k=20:  0.9737196765498652
# Tiempo entrenamiento para k=21  = 112.77341842651367 ms
# Exactitud media obtenida con k-NN para k=21:  0.9730458221024259
# Tiempo entrenamiento para k=22  = 107.75084495544434 ms
# Exactitud media obtenida con k-NN para k=22:  0.9730458221024259
# Tiempo entrenamiento para k=23  = 101.30915641784668 ms
# Exactitud media obtenida con k-NN para k=23:  0.9723719676549866
# Tiempo entrenamiento para k=24  = 116.89538955688477 ms
# Exactitud media obtenida con k-NN para k=24:  0.9730458221024259
# Tiempo entrenamiento para k=25  = 110.36562919616699 ms
# Exactitud media obtenida con k-NN para k=25:  0.9737196765498652
# Tiempo entrenamiento para k=26  = 121.29902839660645 ms
# Exactitud media obtenida con k-NN para k=26:  0.9723719676549866
# Tiempo entrenamiento para k=27  = 119.04525756835938 ms
# Exactitud media obtenida con k-NN para k=27:  0.9710242587601078
# Tiempo entrenamiento para k=28  = 119.2739486694336 ms
# Exactitud media obtenida con k-NN para k=28:  0.9703504043126685
# Tiempo entrenamiento para k=29  = 112.85543441772461 ms
# Exactitud media obtenida con k-NN para k=29:  0.9716981132075472
# Tiempo entrenamiento para k=30  = 120.79553604125977 ms
# Exactitud media obtenida con k-NN para k=30:  0.9716981132075472
# Tiempo entrenamiento para k=31  = 112.98341751098633 ms
# Exactitud media obtenida con k-NN para k=31:  0.9716981132075472
# Tiempo entrenamiento para k=32  = 110.5933666229248 ms
# Exactitud media obtenida con k-NN para k=32:  0.9710242587601078
# Tiempo entrenamiento para k=33  = 111.53082847595215 ms
# Exactitud media obtenida con k-NN para k=33:  0.9703504043126685
# Tiempo entrenamiento para k=34  = 121.56052589416504 ms
# Exactitud media obtenida con k-NN para k=34:  0.9703504043126685
# Tiempo entrenamiento para k=35  = 118.63441467285156 ms
# Exactitud media obtenida con k-NN para k=35:  0.9696765498652291
# Tiempo entrenamiento para k=36  = 125.78544616699219 ms
# Exactitud media obtenida con k-NN para k=36:  0.9703504043126685
# Tiempo entrenamiento para k=37  = 138.14549446105957 ms
# Exactitud media obtenida con k-NN para k=37:  0.9703504043126685
# Tiempo entrenamiento para k=38  = 139.01257514953613 ms
# Exactitud media obtenida con k-NN para k=38:  0.9696765498652291
# Tiempo entrenamiento para k=39  = 140.39411544799805 ms
# Exactitud media obtenida con k-NN para k=39:  0.9696765498652291
# Tiempo entrenamiento para k=40  = 145.25270462036133 ms
# Exactitud media obtenida con k-NN para k=40:  0.9703504043126685
# Tiempo entrenamiento para k=41  = 139.4160270690918 ms
# Exactitud media obtenida con k-NN para k=41:  0.9703504043126685
# Tiempo entrenamiento para k=42  = 139.6005153656006 ms
# Exactitud media obtenida con k-NN para k=42:  0.9703504043126685
# Tiempo entrenamiento para k=43  = 143.59383583068848 ms
# Exactitud media obtenida con k-NN para k=43:  0.9690026954177897
# Tiempo entrenamiento para k=44  = 136.6529941558838 ms
# Exactitud media obtenida con k-NN para k=44:  0.9690026954177897
# Tiempo entrenamiento para k=45  = 152.46448516845703 ms
# Exactitud media obtenida con k-NN para k=45:  0.9609164420485176
# Tiempo entrenamiento para k=46  = 144.79742050170898 ms
# Exactitud media obtenida con k-NN para k=46:  0.9615902964959568
# Tiempo entrenamiento para k=47  = 145.68533897399902 ms
# Exactitud media obtenida con k-NN para k=47:  0.9602425876010782
# Tiempo entrenamiento para k=48  = 150.62212944030762 ms
# Exactitud media obtenida con k-NN para k=48:  0.9615902964959568
# Tiempo entrenamiento para k=49  = 153.01051139831543 ms
# Exactitud media obtenida con k-NN para k=49:  0.9615902964959568
# Tiempo entrenamiento para k=50  = 151.890230178833 ms
# Exactitud media obtenida con k-NN para k=50:  0.9622641509433962
# Tiempo entrenamiento para k=51  = 147.35441207885742 ms
# Exactitud media obtenida con k-NN para k=51:  0.9622641509433962
# Tiempo entrenamiento para k=52  = 141.64705276489258 ms
# Exactitud media obtenida con k-NN para k=52:  0.9622641509433962
# Tiempo entrenamiento para k=53  = 154.10261154174805 ms
# Exactitud media obtenida con k-NN para k=53:  0.9622641509433962
# Tiempo entrenamiento para k=54  = 147.80926704406738 ms
# Exactitud media obtenida con k-NN para k=54:  0.9622641509433962
# Tiempo entrenamiento para k=55  = 152.6297092437744 ms
# Exactitud media obtenida con k-NN para k=55:  0.9622641509433962
# Tiempo entrenamiento para k=56  = 153.15546989440918 ms
# Exactitud media obtenida con k-NN para k=56:  0.9615902964959568
# Tiempo entrenamiento para k=57  = 140.29598236083984 ms
# Exactitud media obtenida con k-NN para k=57:  0.9609164420485176
# Tiempo entrenamiento para k=58  = 147.23854064941406 ms
# Exactitud media obtenida con k-NN para k=58:  0.9609164420485176
# Tiempo entrenamiento para k=59  = 143.4375762939453 ms
# Exactitud media obtenida con k-NN para k=59:  0.9609164420485176
# Tiempo entrenamiento para k=60  = 149.20344352722168 ms
# Exactitud media obtenida con k-NN para k=60:  0.9609164420485176
# Tiempo entrenamiento para k=61  = 153.09205055236816 ms
# Exactitud media obtenida con k-NN para k=61:  0.9609164420485176
# Tiempo entrenamiento para k=62  = 148.84519577026367 ms
# Exactitud media obtenida con k-NN para k=62:  0.9609164420485176
# Tiempo entrenamiento para k=63  = 156.3464641571045 ms
# Exactitud media obtenida con k-NN para k=63:  0.9609164420485176
# Tiempo entrenamiento para k=64  = 148.42767715454102 ms
# Exactitud media obtenida con k-NN para k=64:  0.9609164420485176
# Tiempo entrenamiento para k=65  = 144.68140602111816 ms
# Exactitud media obtenida con k-NN para k=65:  0.9609164420485176
# Tiempo entrenamiento para k=66  = 145.8395481109619 ms
# Exactitud media obtenida con k-NN para k=66:  0.9609164420485176
# Tiempo entrenamiento para k=67  = 151.0305404663086 ms
# Exactitud media obtenida con k-NN para k=67:  0.9609164420485176
# Tiempo entrenamiento para k=68  = 158.10632705688477 ms
# Exactitud media obtenida con k-NN para k=68:  0.9615902964959568
# Tiempo entrenamiento para k=69  = 172.37963676452637 ms
# Exactitud media obtenida con k-NN para k=69:  0.9602425876010782
# Tiempo entrenamiento para k=70  = 162.60061264038086 ms
# Exactitud media obtenida con k-NN para k=70:  0.9595687331536388
# Tiempo entrenamiento para k=71  = 165.07878303527832 ms
# Exactitud media obtenida con k-NN para k=71:  0.9595687331536388
# Tiempo entrenamiento para k=72  = 168.47009658813477 ms
# Exactitud media obtenida con k-NN para k=72:  0.9595687331536388
# Tiempo entrenamiento para k=73  = 183.06894302368164 ms
# Exactitud media obtenida con k-NN para k=73:  0.9582210242587601
# Tiempo entrenamiento para k=74  = 165.3797149658203 ms
# Exactitud media obtenida con k-NN para k=74:  0.9588948787061995
# Tiempo entrenamiento para k=75  = 171.04134559631348 ms
# Exactitud media obtenida con k-NN para k=75:  0.9575471698113207
# Tiempo entrenamiento para k=76  = 173.6948013305664 ms
# Exactitud media obtenida con k-NN para k=76:  0.9588948787061995
# Tiempo entrenamiento para k=77  = 158.38794708251953 ms
# Exactitud media obtenida con k-NN para k=77:  0.9568733153638814
# Tiempo entrenamiento para k=78  = 171.49195671081543 ms
# Exactitud media obtenida con k-NN para k=78:  0.956199460916442
# Tiempo entrenamiento para k=79  = 181.99787139892578 ms
# Exactitud media obtenida con k-NN para k=79:  0.9555256064690026
# Tiempo entrenamiento para k=80  = 178.33824157714844 ms
# Exactitud media obtenida con k-NN para k=80:  0.956199460916442
# Tiempo entrenamiento para k=81  = 176.1183261871338 ms
# Exactitud media obtenida con k-NN para k=81:  0.9555256064690026
# Tiempo entrenamiento para k=82  = 175.93016624450684 ms
# Exactitud media obtenida con k-NN para k=82:  0.9548517520215634
# Tiempo entrenamiento para k=83  = 178.03497314453125 ms
# Exactitud media obtenida con k-NN para k=83:  0.9521563342318059
# Tiempo entrenamiento para k=84  = 159.73286628723145 ms
# Exactitud media obtenida con k-NN para k=84:  0.9528301886792453
# Tiempo entrenamiento para k=85  = 159.05609130859375 ms
# Exactitud media obtenida con k-NN para k=85:  0.9514824797843666
# Tiempo entrenamiento para k=86  = 172.4055290222168 ms
# Exactitud media obtenida con k-NN para k=86:  0.9514824797843666
# Tiempo entrenamiento para k=87  = 170.3434944152832 ms
# Exactitud media obtenida con k-NN para k=87:  0.9508086253369272
# Tiempo entrenamiento para k=88  = 181.3556671142578 ms
# Exactitud media obtenida con k-NN para k=88:  0.9508086253369272
# Tiempo entrenamiento para k=89  = 180.76696395874023 ms
# Exactitud media obtenida con k-NN para k=89:  0.9487870619946092
# Tiempo entrenamiento para k=90  = 179.82745170593262 ms
# Exactitud media obtenida con k-NN para k=90:  0.9508086253369272
# Tiempo entrenamiento para k=91  = 177.05078125 ms
# Exactitud media obtenida con k-NN para k=91:  0.9494609164420486
# Tiempo entrenamiento para k=92  = 181.75301551818848 ms
# Exactitud media obtenida con k-NN para k=92:  0.9494609164420486
# Tiempo entrenamiento para k=93  = 187.82668113708496 ms
# Exactitud media obtenida con k-NN para k=93:  0.9481132075471698
# Tiempo entrenamiento para k=94  = 167.63834953308105 ms
# Exactitud media obtenida con k-NN para k=94:  0.9494609164420486
# Tiempo entrenamiento para k=95  = 193.94726753234863 ms
# Exactitud media obtenida con k-NN para k=95:  0.9474393530997305
# Tiempo entrenamiento para k=96  = 181.20880126953125 ms
# Exactitud media obtenida con k-NN para k=96:  0.9481132075471698
# Tiempo entrenamiento para k=97  = 193.2839870452881 ms
# Exactitud media obtenida con k-NN para k=97:  0.9467654986522911
# Tiempo entrenamiento para k=98  = 170.7118034362793 ms
# Exactitud media obtenida con k-NN para k=98:  0.9474393530997305
# Tiempo entrenamiento para k=99  = 170.40624618530273 ms
# Exactitud media obtenida con k-NN para k=99:  0.9460916442048517

# %%
# Gráfica 1: Antes de Escalar
plt.plot(Posicion,Score, label="Exactitud del modelo")
plt.xticks(np.arange(0, 101, 5))
plt.title('Precisión del modelo undersampling con PCA')
plt.ylabel('Exactitud del modelo')
plt.xlabel('Valor de k')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Gráfica 1: Antes de Escalar
plt.plot(Posicion,Time, label="Tiempo de entrenamiento(ms)")
plt.xticks(np.arange(0, 101, 5))
plt.title('Tiempo de entrenamiento del modelo undersampling sin PCA')
plt.ylabel('Tiempo de entrenamiento(ms)')
plt.xlabel('Valor de k')
plt.legend()

plt.tight_layout()
plt.show()

# %%
Valor_maximo = np.max(Score)
Tiempo_min = np.min(Time)
print(f"El valor máximo de exactitud es de: {Valor_maximo}")
print(f"Y está situado en la posición: {Score.argmax()+1}")
print(f"El valor mínimo de tiempo es de: {Tiempo_min}")
print(f"Y está situado en la posición: {Time.argmin()+1}")
# Out:
# El valor máximo de exactitud es de: 1.0
# Y está situado en la posición: 1
# El valor mínimo de tiempo es de: 6.937742233276367
# Y está situado en la posición: 4

# %% [markdown]
# ### Entrenamiento
# Utilizaremos el algoritmo <code>KNeighborsClassifier</code> de <b>scikit-learn</b> (<a href="https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html?highlight=kneighborsclassifier#sklearn.neighbors.KNeighborsClassifier">documentación del algoritmo</a>).

# %%
k = Score.argmax()    # Número de vecinos

# Creamos nuestra instancia de nuestro algoritmo KNN con 4 vecinos
neigh = KNeighborsClassifier(n_neighbors = k, weights='distance')

ini = time.time() 
#Entrenamiento del modelo, llamando a su método fit 
neigh.fit(X_train,y_train)
print(f"Tiempo entrenamiento = {(time.time() - ini)*1000:.3f} ms")
# Out:
# Tiempo entrenamiento = 1.714 ms

# %% [markdown]
# ### Predicción
# Ahora podemos utilizar nuestro modelo entrenado para realizar predicciones, para ello llamamos al método <code>predict</code> con el conjunto de valores que hemos reservado para test:

# %%
ini = time.time() 
y_predict_knn = neigh.predict(X_test)
print(f"Tiempo de predicción = {(time.time() - ini)*1000:.3f} ms") 

y_predict_knn[0:5] # muestra del resultado de la predicción
# Out:
# Tiempo de predicción = 59.762 ms
# array([0, 0, 0, 1, 0])

# %% [markdown]
# ## Matriz de confusión

# %% [markdown]
# Se muestra a continuación la matriz de confusión ya que esta gráfica nos permite ver fácilmente el número de elemetos que los algoritmos han clasificado correcta e incorrectamente. Para mostrarla utilizamos <code>ConfusionMatrixDisplay</code> (<a href="https://scikit-learn.org/stable/modules/generated/sklearn.metrics.ConfusionMatrixDisplay.html">documentación</a>).

# %%
cm_kNN = confusion_matrix(y_test, y_predict_knn, labels=[0,1])
cm_kNN
# Out:
# array([[808, 132],
#        [507,  37]])

# %%
disp_knn = ConfusionMatrixDisplay(
    confusion_matrix=cm_kNN,
    display_labels=['EDIBLE(0)','POISONOUS(1)']
)
disp_knn.plot(cmap=plt.cm.Blues)
plt.title("Matriz de confusión k-NN")
plt.show()

# %% [markdown]
# ## SVM

# %% [markdown]
# Ahora se entrenará el modelo SVM con los datos obtenidos anteriormente. Para ello realizaremos 2 estudios, el primero consistirá en cambiar el valor de C en el rango de 1-10 para ver de que manera varian los resultados obtenidos, y el segundo será cambiando el tipo de kernel utilizado para tratar de obtener los mejores resultados con nuestro código.
#
# El parametro C es es que controla el peso de los terminos de error, es decir, indica cuanto castiga la SVM los errores de clasificación. Esto quiere decir que con un valor de C alto el sistema será más sensible al ruido y tendrá una tendencia a sobreajustar, lo que lo hace menos fiable en otros conjuntos de datos. Sin embargo para un valor de C bajo el modelo tenderá más a ignorar el ruido presente en el conjunto, pero tiene una mayor tendencia a no capturar bien estructuras complejas. A continuación se harán unos cálculos para cada modelo para poder observar cual es el mejor caso.

# %% [markdown]
# ### kernel linear
#
# Utilizaremos el algoritmo <code>SVC</code> de <b>scikit-learn</b> (<a href="https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html#sklearn.svm.SVC">documentación del algoritmo</a>). Es el algoritmo implementado en <b>scikit-learn</b> para clasificación de <code>SVM</code>.
#
# Una función kernel lineal es la función más simple de todas, esta buscará realizar una frontera lineal para separar las clases.

# %%
Score_linear = np.zeros(10)
Posicion_linear = np.zeros(10)
Time_linear = np.zeros(10)
for i in range(1,11):
    Score_ind=np.zeros(5)
    Posicion_ind=np.zeros(5)
    Time_ind=np.zeros(5)
    for u in range (1,6):
        ini = time.time() 
        clf_svm = svm.SVC(C=i,kernel='linear')
        clf_svm.fit(X_train, y_train) 
        y_predict_svm = clf_svm.predict(X_test)
        Score_ind[u-1] = clf_svm.score(X_test, y_test)
        Posicion_ind[u-1] = i
        Time_ind[u-1] = (time.time() - ini)*1000
    Time_linear[i-1] = np.max(Time_ind)
    Score_linear[i-1] = np.max(Score_ind)
    Posicion_linear[i-1] = i
    print(f"Tiempo entrenamiento para C={i}  = {Time_linear[i-1]} ms") 
    print("Exactitud media obtenida con SVM para C={i}: ".format(i=i), clf_svm.score(X_test, y_test))
# Out:
# Tiempo entrenamiento para C=1  = 95.35884857177734 ms
# Exactitud media obtenida con SVM para C=1:  0.9683288409703504
# Tiempo entrenamiento para C=2  = 86.79056167602539 ms
# Exactitud media obtenida con SVM para C=2:  0.9764150943396226
# Tiempo entrenamiento para C=3  = 56.276798248291016 ms
# Exactitud media obtenida con SVM para C=3:  0.9797843665768194
# Tiempo entrenamiento para C=4  = 55.7861328125 ms
# Exactitud media obtenida con SVM para C=4:  0.9932614555256065
# Tiempo entrenamiento para C=5  = 57.669639587402344 ms
# Exactitud media obtenida con SVM para C=5:  0.9932614555256065
# Tiempo entrenamiento para C=6  = 51.81407928466797 ms
# Exactitud media obtenida con SVM para C=6:  0.9932614555256065
# Tiempo entrenamiento para C=7  = 55.873870849609375 ms
# Exactitud media obtenida con SVM para C=7:  0.9845013477088949
# Tiempo entrenamiento para C=8  = 52.036285400390625 ms
# Exactitud media obtenida con SVM para C=8:  0.9845013477088949
# Tiempo entrenamiento para C=9  = 51.80621147155762 ms
# Exactitud media obtenida con SVM para C=9:  0.9845013477088949
# Tiempo entrenamiento para C=10  = 52.81686782836914 ms
# Exactitud media obtenida con SVM para C=10:  0.9845013477088949

# %%
Valor_maximo = np.max(Score_linear)
Tiempo_min = np.min(Time_linear)

print(f"El valor máximo de exactitud es de: {Valor_maximo}")
print(f"Y está situado en la posición: {Score_linear.argmax()}")
print(f"El valor mínimo de tiempo es de: {Tiempo_min}")
print(f"Y está situado en la posición: {Time_linear.argmin()}")

clf_svm = svm.SVC(C=Score_linear.argmax(),kernel='linear')

ini = time.time() 
#Entrenamiento del modelo, llamando a su método fit 
clf_svm.fit(X_train, y_train) 
print(f"Tiempo entrenamiento = {(time.time() - ini)*1000:.3f} ms")
# Out:
# El valor máximo de exactitud es de: 0.6361185983827493
# Y está situado en la posición: 5
# El valor mínimo de tiempo es de: 27.584075927734375
# Y está situado en la posición: 3
# Tiempo entrenamiento = 55.410 ms

# %% [markdown]
# ### Entrenamiento
# Utilizaremos el algoritmo <code>SVC</code> de <b>scikit-learn</b> (<a href="https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html#sklearn.svm.SVC">documentación del algoritmo</a>). Es el algoritmo implementado en <b>scikit-learn</b> para clasificación de <code>SVM</code>.

# %%
clf_svm = svm.SVC(C=(Score_linear.argmax())+1,kernel='linear')

ini = time.time() 
#Entrenamiento del modelo, llamando a su método fit 
clf_svm.fit(X_train, y_train) 
print(f"Tiempo entrenamiento = {(time.time() - ini)*1000:.3f} ms")
# Out:
# Tiempo entrenamiento = 45.135 ms

# %% [markdown]
# ### Predicción
# Ahora podemos utilizar nuestro modelo entrenado para realizar predicciones, para ello llamamos al método <code>predict</code> con el conjunto de valores que hemos reservado para test:

# %%
ini = time.time() 
y_predict_svm = clf_svm.predict(X_test)
print(f"Tiempo de predicción = {(time.time() - ini)*1000:.3f} ms") 

y_predict_svm [0:5] # muestra del resultado de la predicción
# Out:
# Tiempo de predicción = 2.867 ms
# array([0, 0, 0, 1, 0])

# %% [markdown]
# ## Matriz de confusión

# %% [markdown]
# Se muestra a continuación la matriz de confusión ya que esta gráfica nos permite ver fácilmente el número de elemetos que los algoritmos han clasificado correcta e incorrectamente. Para mostrarla utilizamos <code>ConfusionMatrixDisplay</code> (<a href="https://scikit-learn.org/stable/modules/generated/sklearn.metrics.ConfusionMatrixDisplay.html">documentación</a>).

# %%
cm_SVM = confusion_matrix(y_test, y_predict_svm, labels=[0,1])
cm_SVM
# Out:
# array([[902,  38],
#        [  6, 538]])

# %%
disp_SVM = ConfusionMatrixDisplay(
    confusion_matrix=cm_SVM,
    display_labels=['EDIBLE(0)','POISONOUS(1)']
)
disp_SVM.plot(cmap=plt.cm.Blues)
plt.title("Matriz de confusión SVM")
plt.show()

# %% [markdown]
# ### Conclusiones
#
# Este modelo podemos observar que llega a una gran precisión, 97.76%, para valores de C altos, pero esto también influye en los tiempos que le lleva tanto entrenar el modelo como realizar los test. Por lo tanto, se buscará la obtención de mejores resultados o resultados similares para un valor de C más bajo en otros modelos. Además, se buscará también reducir los tiempos de entrenamiento ya que para estos casos de tan alta precisión los tiempos son bastante más elevados que los observados en el modelo k-nn.

# %% [markdown]
# ### kernel RBF
#
# Utilizaremos el algoritmo <code>SVC</code> de <b>scikit-learn</b> (<a href="https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html#sklearn.svm.SVC">documentación del algoritmo</a>). Es el algoritmo implementado en <b>scikit-learn</b> para clasificación de <code>SVM</code>.
#
# Este se trata del modelo kernel más usado en SVM ya que permite crear fronteras de decisión no lineales, muy flexibles y capaces de adaptarse a datos complejos. Para esto este algoritmo busca similitudes entre aquellos puntos muy cercanos entre si y, al proyectarlos en un espacio con muchas dimensiones permite dibujar fronteras curvas y ajustadas a las necesidades del conjunto de datos.

# %%
Score_rbf = np.zeros(10)
Posicion_rbf = np.zeros(10)
Time_rbf = np.zeros(10)
for i in range(1,11):
    Score_ind1=np.zeros(5)
    Posicion_ind1=np.zeros(5)
    Time_ind1=np.zeros(5)
    for u in range (1,6):
        ini = time.time() 
        clf_svm = svm.SVC(C=i,kernel='rbf')
        clf_svm.fit(X_train, y_train) 
        y_predict_svm = clf_svm.predict(X_test)
        Score_ind1[u-1] = clf_svm.score(X_test, y_test)
        Posicion_ind1[u-1] = i
        Time_ind1[u-1] = (time.time() - ini)*1000
    Time_rbf[i-1] = np.max(Time_ind1)
    Score_rbf[i-1] = np.max(Score_ind1)
    Posicion_rbf[i-1] = i
    print(f"Tiempo entrenamiento para C={i}  = {Time_rbf[i-1]} ms") 
    print("Exactitud media obtenida con SVM para C={i}: ".format(i=i), clf_svm.score(X_test, y_test))
# Out:
# Tiempo entrenamiento para C=1  = 51.08475685119629 ms
# Exactitud media obtenida con SVM para C=1:  1.0
# Tiempo entrenamiento para C=2  = 33.161163330078125 ms
# Exactitud media obtenida con SVM para C=2:  1.0
# Tiempo entrenamiento para C=3  = 34.0728759765625 ms
# Exactitud media obtenida con SVM para C=3:  1.0
# Tiempo entrenamiento para C=4  = 34.783363342285156 ms
# Exactitud media obtenida con SVM para C=4:  1.0
# Tiempo entrenamiento para C=5  = 33.21027755737305 ms
# Exactitud media obtenida con SVM para C=5:  1.0
# Tiempo entrenamiento para C=6  = 31.325578689575195 ms
# Exactitud media obtenida con SVM para C=6:  1.0
# Tiempo entrenamiento para C=7  = 30.446290969848633 ms
# Exactitud media obtenida con SVM para C=7:  1.0
# Tiempo entrenamiento para C=8  = 31.14008903503418 ms
# Exactitud media obtenida con SVM para C=8:  1.0
# Tiempo entrenamiento para C=9  = 34.32750701904297 ms
# Exactitud media obtenida con SVM para C=9:  1.0
# Tiempo entrenamiento para C=10  = 31.61454200744629 ms
# Exactitud media obtenida con SVM para C=10:  1.0

# %%
Valor_maximo = np.max(Score_rbf)
Tiempo_min = np.min(Time_rbf)

print(f"El valor máximo de exactitud es de: {Valor_maximo}")
print(f"Y está situado en la posición: {Score_rbf.argmax()}")
print(f"El valor mínimo de tiempo es de: {Tiempo_min}")
print(f"Y está situado en la posición: {Time_rbf.argmin()}")

clf_svm = svm.SVC(C=Score_rbf.argmax(),kernel='rbf')

ini = time.time() 
#Entrenamiento del modelo, llamando a su método fit 
clf_svm.fit(X_train, y_train) 
print(f"Tiempo entrenamiento = {(time.time() - ini)*1000:.3f} ms")
# Out:
# El valor máximo de exactitud es de: 1.0
# Y está situado en la posición: 0
# El valor mínimo de tiempo es de: 30.446290969848633
# Y está situado en la posición: 6
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[64], line 13
#      11 ini = time.time()
#      12 #Entrenamiento del modelo, llamando a su método fit
# ---> 13 clf_svm.fit(X_train, y_train)
#      14 print(f"Tiempo entrenamiento = {(time.time() - ini)*1000:.3f} ms")
#
# File c:\Users\alvar\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\base.py:1329, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1324 partial_fit_and_fitted = (
#    1325     fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1326 )
#    1328 if not global_skip_validation and not partial_fit_and_fitted:
# -> 1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
#    1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\alvar\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\base.py:492, in BaseEstimator._validate_params(self)
#     484 def _validate_params(self):
#     485     """Validate types and values of constructor parameters
#     486
#     487     The expected type and values must be defined in the `_parameter_constraints`
#    (...)    490     accepted constraints.
#     491     """
# --> 492     validate_parameter_constraints(
#     493         self._parameter_constraints,
#     494         self.get_params(deep=False),
#     495         caller_name=self.__class__.__name__,
#     496     )
#
# File c:\Users\alvar\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\_param_validation.py:98, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      92 else:
#      93     constraints_str = (
#      94         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      95         f" {constraints[-1]}"
#      96     )
# ---> 98 raise InvalidParameterError(
#      99     f"The {param_name!r} parameter of {caller_name} must be"
#     100     f" {constraints_str}. Got {param_val!r} instead."
#     101 )
#
# InvalidParameterError: The 'C' parameter of SVC must be a float in the range (0.0, inf]. Got np.int64(0) instead.

# %% [markdown]
# ### Entrenamiento
# Utilizaremos el algoritmo <code>SVC</code> de <b>scikit-learn</b> (<a href="https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html#sklearn.svm.SVC">documentación del algoritmo</a>). Es el algoritmo implementado en <b>scikit-learn</b> para clasificación de <code>SVM</code>.

# %%
clf_svm = svm.SVC(C=(Score_rbf.argmax())+1,kernel='rbf')

ini = time.time() 
#Entrenamiento del modelo, llamando a su método fit 
clf_svm.fit(X_train, y_train) 
print(f"Tiempo entrenamiento = {(time.time() - ini)*1000:.3f} ms")
# Out:
# Tiempo entrenamiento = 16.851 ms

# %% [markdown]
# ### Predicción
# Ahora podemos utilizar nuestro modelo entrenado para realizar predicciones, para ello llamamos al método <code>predict</code> con el conjunto de valores que hemos reservado para test:

# %%
ini = time.time() 
y_predict_svm = clf_svm.predict(X_test)
print(f"Tiempo de predicción = {(time.time() - ini)*1000:.3f} ms") 

y_predict_svm [0:5] # muestra del resultado de la predicción
# Out:
# Tiempo de predicción = 8.519 ms
# array([0, 0, 0, 1, 0])

# %% [markdown]
# ## Matriz de confusión

# %% [markdown]
# Se muestra a continuación la matriz de confusión ya que esta gráfica nos permite ver fácilmente el número de elemetos que los algoritmos han clasificado correcta e incorrectamente. Para mostrarla utilizamos <code>ConfusionMatrixDisplay</code> (<a href="https://scikit-learn.org/stable/modules/generated/sklearn.metrics.ConfusionMatrixDisplay.html">documentación</a>).

# %%
cm_SVM = confusion_matrix(y_test, y_predict_svm, labels=[0,1])
cm_SVM
# Out:
# array([[926,  14],
#        [  0, 544]])

# %%
disp_SVM = ConfusionMatrixDisplay(
    confusion_matrix=cm_SVM,
    display_labels=['EDIBLE(0)','POISONOUS(1)']
)
disp_SVM.plot(cmap=plt.cm.Blues)
plt.title("Matriz de confusión SVM")
plt.show()

# %% [markdown]
# ### Conclusiones
#
# Utilizando este modelo se pueden observar los mejores resultados que se han obtenido hasta el momento, con un

# %% [markdown]
# ### kernel Polinómico
#
# Utilizaremos el algoritmo <code>SVC</code> de <b>scikit-learn</b> (<a href="https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html#sklearn.svm.SVC">documentación del algoritmo</a>). Es el algoritmo implementado en <b>scikit-learn</b> para clasificación de <code>SVM</code>.
#
# Para el caso de una función polinómica, también se busca conseguir fronteras de decisión curvas pero, en este caso, la complejidad de la curva se controlará con el grado del polinomio. Este modelo se suele utilizar para aquellos casos en los que la frontera no es lineal, pero tampoco es extremadamente complicada.

# %%
Score_poly = np.zeros(10)
Posicion_poly = np.zeros(10)
Time_poly = np.zeros(10)
for i in range(1,11):  
    Score_ind=np.zeros(5)
    Posicion_ind=np.zeros(5)
    Time_ind=np.zeros(5)
    for u in range (1,6):
        ini = time.time() 
        
        clf_svm = svm.SVC(C=i,kernel='poly')
        clf_svm.fit(X_train, y_train) 
        y_predict_svm = clf_svm.predict(X_test)
    
        Score_ind[u-1] = clf_svm.score(X_test, y_test)
        Posicion_ind[u-1] = i
        Time_ind[u-1] = (time.time() - ini)*1000
    Time_poly[i-1] = np.max(Time_ind)
    Score_poly[i-1] = np.max(Score_ind)
    Posicion_poly[i-1] = i
    print(f"Tiempo entrenamiento para C={i}  = {Time_poly[i-1]} ms") 
    print("Exactitud media obtenida con SVM para C={i}: ".format(i=i), clf_svm.score(X_test, y_test))
# Out:
# Tiempo entrenamiento para C=1  = 60.20545959472656 ms
# Exactitud media obtenida con SVM para C=1:  0.6994609164420486
# Tiempo entrenamiento para C=2  = 27.72045135498047 ms
# Exactitud media obtenida con SVM para C=2:  0.7068733153638814
# Tiempo entrenamiento para C=3  = 24.556875228881836 ms
# Exactitud media obtenida con SVM para C=3:  0.7102425876010782
# Tiempo entrenamiento para C=4  = 26.360273361206055 ms
# Exactitud media obtenida con SVM para C=4:  0.7102425876010782
# Tiempo entrenamiento para C=5  = 32.57036209106445 ms
# Exactitud media obtenida con SVM para C=5:  0.7102425876010782
# Tiempo entrenamiento para C=6  = 25.793790817260742 ms
# Exactitud media obtenida con SVM para C=6:  0.7102425876010782
# Tiempo entrenamiento para C=7  = 24.744749069213867 ms
# Exactitud media obtenida con SVM para C=7:  0.7102425876010782
# Tiempo entrenamiento para C=8  = 23.567914962768555 ms
# Exactitud media obtenida con SVM para C=8:  0.7102425876010782
# Tiempo entrenamiento para C=9  = 26.932477951049805 ms
# Exactitud media obtenida con SVM para C=9:  0.7102425876010782
# Tiempo entrenamiento para C=10  = 24.540424346923828 ms
# Exactitud media obtenida con SVM para C=10:  0.7102425876010782

# %%
Valor_maximo = np.max(Score_poly)
Tiempo_min = np.min(Time_poly)

print(f"El valor máximo de exactitud es de: {Valor_maximo}")
print(f"Y está situado en la posición: {Score_poly.argmax()}")
print(f"El valor mínimo de tiempo es de: {Tiempo_min}")
print(f"Y está situado en la posición: {Time_poly.argmin()}")

clf_svm = svm.SVC(C=Score_poly.argmax(),kernel='poly')

ini = time.time() 
#Entrenamiento del modelo, llamando a su método fit 
clf_svm.fit(X_train, y_train) 
print(f"Tiempo entrenamiento = {(time.time() - ini)*1000:.3f} ms")
# Out:
# El valor máximo de exactitud es de: 0.9191374663072777
# Y está situado en la posición: 2
# El valor mínimo de tiempo es de: 18.28765869140625
# Y está situado en la posición: 2
# Tiempo entrenamiento = 16.651 ms

# %% [markdown]
# ### Entrenamiento
# Utilizaremos el algoritmo <code>SVC</code> de <b>scikit-learn</b> (<a href="https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html#sklearn.svm.SVC">documentación del algoritmo</a>). Es el algoritmo implementado en <b>scikit-learn</b> para clasificación de <code>SVM</code>.

# %%
clf_svm = svm.SVC(C=(Score_poly.argmax())+1,kernel='poly')

ini = time.time() 
#Entrenamiento del modelo, llamando a su método fit 
clf_svm.fit(X_train, y_train) 
print(f"Tiempo entrenamiento = {(time.time() - ini)*1000:.3f} ms")
# Out:
# Tiempo entrenamiento = 16.792 ms

# %% [markdown]
# ### Predicción
# Ahora podemos utilizar nuestro modelo entrenado para realizar predicciones, para ello llamamos al método <code>predict</code> con el conjunto de valores que hemos reservado para test:

# %%
ini = time.time() 
y_predict_svm = clf_svm.predict(X_test)
print(f"Tiempo de predicción = {(time.time() - ini)*1000:.3f} ms") 

y_predict_svm [0:5] # muestra del resultado de la predicción
# Out:
# Tiempo de predicción = 1.802 ms
# array([0, 0, 0, 1, 0])

# %% [markdown]
# ## Matriz de confusión
#
# Se muestra a continuación la matriz de confusión ya que esta gráfica nos permite ver fácilmente el número de elemetos que los algoritmos han clasificado correcta e incorrectamente. Para mostrarla utilizamos <code>ConfusionMatrixDisplay</code> (<a href="https://scikit-learn.org/stable/modules/generated/sklearn.metrics.ConfusionMatrixDisplay.html">documentación</a>).

# %%
cm_SVM = confusion_matrix(y_test, y_predict_svm, labels=[0,1])
cm_SVM
# Out:
# array([[820, 120],
#        [  0, 544]])

# %%
disp_SVM = ConfusionMatrixDisplay(
    confusion_matrix=cm_SVM,
    display_labels=['EDIBLE(0)','POISONOUS(1)']
)
disp_SVM.plot(cmap=plt.cm.Blues)
plt.title("Matriz de confusión SVM")
plt.show()

# %% [markdown]
# ### Conclusiones
#
# A pesar de que los resultados son bastante buenos, se obtiene un 92% de precisión aproximadamente, se puede observar como el aumento de "C" no genera practicamente ningún tipo de cambio en los resultados obtenidos, unicamente en el aumento del tiempo de entrenamiento. Otro detalle a valorar es la diferencia en tiempos de entrenamiento entre los metodos "linear", "RBF" y "poly" ya que para el caso de la función polinómica, esta reduce considerablemente este tiempo de entrenamiento.

# %% [markdown]
# ## CASOS A ESTUDIAR
#
# 1- TODO PREPROCESADO
# 2- CONJUNTO DE DATOS BANILA
# 3- SOLO BALANCEADO DE DATOS: TODO PREPROCESADO - PCA - NORMALIZADO
# 4- TODO PREPROCESADO - NORMALIZADO

# %% [markdown]
# <a name="classification"></a>
# <div class="alert alert-block alert-info"
#      style="border: 0px solid #d60e8c; border-radius: 10px; background:#d60e8c; color: white;">
#       <h2>Código preliminar y de pruebas</h2>
#     <hr style="border: 0.5px solid #ffffff;">
#    <ul style="margin-bottom: 20px;">
# </div>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import time

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn import preprocessing
from sklearn.decomposition import PCA
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import NearMiss

df_orig=pd.read_csv('mushroms1.csv', na_values=["?"])
df_orig.head()
df_orig.isnull().sum()
df=df_orig.dropna(axis=0)
df.isnull().sum()

#Pasamos de texto a numero
encoder = preprocessing.OrdinalEncoder(dtype=int)
df_encoded = encoder.fit_transform(df[['poisonous', "cap-shape","cap-surface","cap-color","bruises","odor",
                                      "gill-attachment","gill-spacing","gill-size","gill-color","stalk-shape","stalk-root",
                                      "stalk-surface-above-ring","stalk-surface-below-ring","stalk-color-above-ring",
                                      "stalk-color-below-ring","veil-type","veil-color","ring-number","ring-type",
                                      "spore-print-color","population","habitat"]])
encoder.categories_
df_encoded
df["poisonous"] = df_encoded[:,0]
df["cap-shape"] = df_encoded[:,1]
df["cap-surface"] = df_encoded[:,2]
df["cap-color"] = df_encoded[:,3]
df["bruises"] = df_encoded[:,4]
df["odor"] = df_encoded[:,5]
df["gill-attachment"] = df_encoded[:,6]
df["gill-spacing"] = df_encoded[:,7]
df["gill-size"] = df_encoded[:,8]
df["gill-color"] = df_encoded[:,9]
df["stalk-shape"] = df_encoded[:,10]
df["stalk-root"] = df_encoded[:,11]
df["stalk-surface-above-ring"] = df_encoded[:,12]
df["stalk-surface-below-ring"] = df_encoded[:,13]
df["stalk-color-above-ring"] = df_encoded[:,14]
df["stalk-color-below-ring"] = df_encoded[:,15]
df["veil-type"] = df_encoded[:,16]
df["veil-color"] = df_encoded[:,17]
df["ring-number"] = df_encoded[:,18]
df["ring-type"] = df_encoded[:,19]
df["spore-print-color"] = df_encoded[:,20]
df["population"] = df_encoded[:,21]
df["habitat"] = df_encoded[:,22]
df.head()

df.shape
df['poisonous'].value_counts()
df.columns
feature_df = df[df.columns[1:df.shape[1]]]
X = feature_df


y = df['poisonous']

y[0:5] 

X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=4)
print ('Training set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)

print ('Conjunto entrenamiento original', X_train.shape,  y_train.shape)
unique, counts = np.unique(y_train, return_counts=True)
print(dict(zip(unique, counts)))

sm = NearMiss()
X_train, y_train= sm.fit_resample(X_train, y_train)


print('\nBalanceado:', X_train.shape,  y_train.shape)
unique, counts = np.unique(y_train, return_counts=True)
print(dict(zip(unique, counts)))



Score = np.zeros(99)
Posicion = np.zeros(99)
for i in range(1,100):
    k = i   
    

    neigh = KNeighborsClassifier(n_neighbors = k)
    neigh.fit(X_train,y_train)
    y_predict_knn = neigh.predict(X_test)
    
    
    Score[i-1] = neigh.score(X_test, y_test)
    Posicion[i-1] = i
    print("Exactitud media obtenida con k-NN para k={i}: ".format(i=i), neigh.score(X_test, y_test))
# Out:
# Training set: (4748, 22) (4748,)
# Test set: (1188, 22) (1188,)
# Conjunto entrenamiento original (4748, 22) (4748,)
# {np.int64(0): np.int64(3008), np.int64(1): np.int64(1740)}
#
# Balanceado: (3480, 22) (3480,)
# {np.int64(0): np.int64(1740), np.int64(1): np.int64(1740)}
# Exactitud media obtenida con k-NN para k=1:  0.9806397306397306
# Exactitud media obtenida con k-NN para k=2:  0.9806397306397306
# Exactitud media obtenida con k-NN para k=3:  0.9747474747474747
# Exactitud media obtenida con k-NN para k=4:  0.9747474747474747
# Exactitud media obtenida con k-NN para k=5:  0.9705387205387206
# Exactitud media obtenida con k-NN para k=6:  0.9688552188552189
# Exactitud media obtenida con k-NN para k=7:  0.9562289562289562
# Exactitud media obtenida con k-NN para k=8:  0.9570707070707071
# Exactitud media obtenida con k-NN para k=9:  0.9562289562289562
# Exactitud media obtenida con k-NN para k=10:  0.9562289562289562
# Exactitud media obtenida con k-NN para k=11:  0.9537037037037037
# Exactitud media obtenida con k-NN para k=12:  0.9553872053872053
# Exactitud media obtenida con k-NN para k=13:  0.9545454545454546
# Exactitud media obtenida con k-NN para k=14:  0.9553872053872053
# Exactitud media obtenida con k-NN para k=15:  0.9528619528619529
# Exactitud media obtenida con k-NN para k=16:  0.9562289562289562
# Exactitud media obtenida con k-NN para k=17:  0.9545454545454546
# Exactitud media obtenida con k-NN para k=18:  0.9537037037037037
# Exactitud media obtenida con k-NN para k=19:  0.9545454545454546
# Exactitud media obtenida con k-NN para k=20:  0.9553872053872053
# Exactitud media obtenida con k-NN para k=21:  0.9486531986531986
# Exactitud media obtenida con k-NN para k=22:  0.9494949494949495
# Exactitud media obtenida con k-NN para k=23:  0.9478114478114478
# Exactitud media obtenida con k-NN para k=24:  0.9494949494949495
# Exactitud media obtenida con k-NN para k=25:  0.9486531986531986
# Exactitud media obtenida con k-NN para k=26:  0.9494949494949495
# Exactitud media obtenida con k-NN para k=27:  0.9444444444444444
# Exactitud media obtenida con k-NN para k=28:  0.9444444444444444
# Exactitud media obtenida con k-NN para k=29:  0.9436026936026936
# Exactitud media obtenida con k-NN para k=30:  0.9444444444444444
# Exactitud media obtenida con k-NN para k=31:  0.9452861952861953
# Exactitud media obtenida con k-NN para k=32:  0.9444444444444444
# Exactitud media obtenida con k-NN para k=33:  0.9436026936026936
# Exactitud media obtenida con k-NN para k=34:  0.9427609427609428
# Exactitud media obtenida con k-NN para k=35:  0.9444444444444444
# Exactitud media obtenida con k-NN para k=36:  0.9452861952861953
# Exactitud media obtenida con k-NN para k=37:  0.9452861952861953
# Exactitud media obtenida con k-NN para k=38:  0.9461279461279462
# Exactitud media obtenida con k-NN para k=39:  0.9427609427609428
# Exactitud media obtenida con k-NN para k=40:  0.9410774410774411
# Exactitud media obtenida con k-NN para k=41:  0.9402356902356902
# Exactitud media obtenida con k-NN para k=42:  0.9393939393939394
# Exactitud media obtenida con k-NN para k=43:  0.9335016835016835
# Exactitud media obtenida con k-NN para k=44:  0.9335016835016835
# Exactitud media obtenida con k-NN para k=45:  0.9259259259259259
# Exactitud media obtenida con k-NN para k=46:  0.9276094276094277
# Exactitud media obtenida con k-NN para k=47:  0.9234006734006734
# Exactitud media obtenida con k-NN para k=48:  0.9175084175084175
# Exactitud media obtenida con k-NN para k=49:  0.9099326599326599
# Exactitud media obtenida con k-NN para k=50:  0.9116161616161617
# Exactitud media obtenida con k-NN para k=51:  0.9048821548821548
# Exactitud media obtenida con k-NN para k=52:  0.9107744107744108
# Exactitud media obtenida con k-NN para k=53:  0.9023569023569024
# Exactitud media obtenida con k-NN para k=54:  0.9006734006734006
# Exactitud media obtenida con k-NN para k=55:  0.8855218855218855
# Exactitud media obtenida con k-NN para k=56:  0.8855218855218855
# Exactitud media obtenida con k-NN para k=57:  0.8813131313131313
# Exactitud media obtenida con k-NN para k=58:  0.8804713804713805
# Exactitud media obtenida con k-NN para k=59:  0.8779461279461279
# Exactitud media obtenida con k-NN para k=60:  0.8796296296296297
# Exactitud media obtenida con k-NN para k=61:  0.8661616161616161
# Exactitud media obtenida con k-NN para k=62:  0.8661616161616161
# Exactitud media obtenida con k-NN para k=63:  0.8602693602693603
# Exactitud media obtenida con k-NN para k=64:  0.8627946127946128
# Exactitud media obtenida con k-NN para k=65:  0.8543771043771043
# Exactitud media obtenida con k-NN para k=66:  0.8585858585858586
# Exactitud media obtenida con k-NN para k=67:  0.8476430976430976
# Exactitud media obtenida con k-NN para k=68:  0.8493265993265994
# Exactitud media obtenida con k-NN para k=69:  0.8442760942760943
# Exactitud media obtenida con k-NN para k=70:  0.8476430976430976
# Exactitud media obtenida con k-NN para k=71:  0.8442760942760943
# Exactitud media obtenida con k-NN para k=72:  0.8451178451178452
# Exactitud media obtenida con k-NN para k=73:  0.8417508417508418
# Exactitud media obtenida con k-NN para k=74:  0.8434343434343434
# Exactitud media obtenida con k-NN para k=75:  0.8442760942760943
# Exactitud media obtenida con k-NN para k=76:  0.8434343434343434
# Exactitud media obtenida con k-NN para k=77:  0.8442760942760943
# Exactitud media obtenida con k-NN para k=78:  0.8434343434343434
# Exactitud media obtenida con k-NN para k=79:  0.8425925925925926
# Exactitud media obtenida con k-NN para k=80:  0.8434343434343434
# Exactitud media obtenida con k-NN para k=81:  0.8417508417508418
# Exactitud media obtenida con k-NN para k=82:  0.8434343434343434
# Exactitud media obtenida con k-NN para k=83:  0.8451178451178452
# Exactitud media obtenida con k-NN para k=84:  0.8451178451178452
# Exactitud media obtenida con k-NN para k=85:  0.8375420875420876
# Exactitud media obtenida con k-NN para k=86:  0.8417508417508418
# Exactitud media obtenida con k-NN para k=87:  0.8375420875420876
# Exactitud media obtenida con k-NN para k=88:  0.8392255892255892
# Exactitud media obtenida con k-NN para k=89:  0.8358585858585859
# Exactitud media obtenida con k-NN para k=90:  0.8375420875420876
# Exactitud media obtenida con k-NN para k=91:  0.8291245791245792
# Exactitud media obtenida con k-NN para k=92:  0.8291245791245792
# Exactitud media obtenida con k-NN para k=93:  0.8282828282828283
# Exactitud media obtenida con k-NN para k=94:  0.82996632996633
# Exactitud media obtenida con k-NN para k=95:  0.8249158249158249
# Exactitud media obtenida con k-NN para k=96:  0.8265993265993266
# Exactitud media obtenida con k-NN para k=97:  0.8249158249158249
# Exactitud media obtenida con k-NN para k=98:  0.8265993265993266
# Exactitud media obtenida con k-NN para k=99:  0.8257575757575758

# %%
for i in range(1, 100):
    k = i

    # Creamos nuestra instancia del modelo
    neigh = KNeighborsClassifier(n_neighbors = k)

    ini = time.time() 
    #Entrenamiento del modelo, llamando a su método fit 
    neigh.fit(X_train,y_train)
    #print(f"Tiempo entrenamiento = {(time.time() - ini)*1000:.3f} ms") 

    ini = time.time() 
    y_predict_knn = neigh.predict(X_test)
    #print(f"Tiempo de predicción = {(time.time() - ini)*1000:.3f} ms") 

    y_predict_knn[0:5] # muestra del resultado de la predicción

    print("Exactitud media obtenida con k-NN para k={i}: ".format(i=i), neigh.score(X_test, y_test))

# %% [markdown]
# <br/><br/>
# <hr style="border: 0.5px solid #d60e8c;">
# <div style="text-align:right;">
# MASTER UNIVERSITARIO EN INGENIERÍA INDUSTRIAL
# </div>
